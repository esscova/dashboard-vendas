# %%
import pandas as pd

# %%
df = pd.read_parquet('../data/produtos.parquet')
df
# Out:
#                        Produto   Categoria do Produto   Preço      Frete  \
# 0          Modelagem preditiva                 livros   92.45   5.609697
# 1     Iniciando em programação                 livros   43.84   0.000000
# 2                     Pandeiro  instrumentos musicais   87.18   2.226512
# 3               Corda de pular        esporte e lazer   13.65   1.257926
# 4               Dinossauro Rex             brinquedos   28.32   2.039059
# ...                        ...                    ...     ...        ...
# 9430                Impressora            eletronicos  472.77  25.456706
# 9431   Dashboards com Power BI                 livros   54.85   3.451702
# 9432           Cubo mágico 8x8             brinquedos   19.74   0.000000
# 9433                  Faqueiro  utilidades domesticas   52.49   0.000000
# 9434               Micro-ondas       eletrodomesticos  711.30  35.459024
#
#      Data da Compra          Vendedor Local da compra  Avaliação da compra  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9435 entries, 0 to 9434
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Produto                 9435 non-null   object
#  1   Categoria do Produto    9435 non-null   object
#  2   Preço                   9435 non-null   float64
#  3   Frete                   9435 non-null   float64
#  4   Data da Compra          9435 non-null   datetime64[ns]
#  5   Vendedor                9435 non-null   object
#  6   Local da compra         9435 non-null   object
#  7   Avaliação da compra     9435 non-null   int64
#  8   Tipo de pagamento       9435 non-null   object
#  9   Quantidade de parcelas  9435 non-null   int64
#  10  lat                     9435 non-null   float64
#  11  lon                     9435 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(2), object(5)
# memory usage: 884.7+ KB

# %%
df.isna().sum()
# Out:
# Produto                   0
# Categoria do Produto      0
# Preço                     0
# Frete                     0
# Data da Compra            0
# Vendedor                  0
# Local da compra           0
# Avaliação da compra       0
# Tipo de pagamento         0
# Quantidade de parcelas    0
# lat                       0
# lon                       0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Produto                   0
# Categoria do Produto      0
# Preço                     0
# Frete                     0
# Data da Compra            0
# Vendedor                  0
# Local da compra           0
# Avaliação da compra       0
# Tipo de pagamento         0
# Quantidade de parcelas    0
# lat                       0
# lon                       0
# dtype: int64

# %%
df.iloc[:, :-2].select_dtypes(include='number').describe()
# Out:
#              Preço        Frete  Avaliação da compra  Quantidade de parcelas
# count  9435.000000  9435.000000          9435.000000             9435.000000
# mean    622.309570    33.167002             4.014520                2.927398
# std     787.094508    41.973711             1.390518                2.802776
# min      10.070000     0.000000             1.000000                1.000000
# 25%      73.610000     4.009423             3.000000                1.000000
# 50%     295.350000    15.648481             5.000000                1.000000
# 75%     884.405000    46.591030             5.000000                4.000000
# max    3969.380000   216.707633             5.000000               24.000000

# %%
df.groupby('Vendedor')['Preço'].agg(['sum', 'count'])
# Out:
#                         sum  count
# Vendedor
# Beatriz Moraes    403594.08    650
# Bianca Santos     399447.52    679
# Bruno Rodrigues   388833.65    684
# Camila Ribeiro    404245.51    667
# Felipe Santos     471727.50    701
# Isabella Pereira  391225.41    650
# João Souza        411416.10    694
# Juliana Costa     451153.64    677
# Larissa Alves     466258.85    679
# Lucas Oliveira    407203.55    674
# Mariana Ferreira  377735.58    656
# Pedro Gomes       417803.49    655
# Rafael Costa      413723.01    625
# Thiago Silva      467122.90    744

# %%
df['Local da compra'].value_counts()
# Out:
# Local da compra
# SP    3943
# RJ    1212
# MG    1102
# RS     534
# PR     473
# SC     346
# BA     310
# DF     242
# GO     186
# PE     181
# ES     171
# CE     151
# MS      82
# PA      81
# MT      80
# MA      62
# RN      48
# PB      46
# AL      41
# PI      40
# TO      29
# SE      28
# RO      19
# AM      14
# AP       9
# AC       3
# RR       2
# Name: count, dtype: int64

# %%
df['Preço'].plot()
# Out:
# <Axes: >

# %%
df['Preço'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
